# %%
import pandas as pd
df_orders = pd.DataFrame(pd.read_csv("C:\\Users\\JSILL\\Downloads\\orders_final.csv"))
print(df_orders)
# Out:
#          Unnamed: 0 RESTAURANT_ID       ...1  ORDER_ID             DATETIME  \
# 0                 1        R10001        0.0  O2226026  2018-12-07 19:17:45
# 1                 2        R10001   797162.0  O1734393  2018-09-28 14:41:22
# 2                 3        R10001   797163.0  O1638120  2018-09-13 18:43:51
# 3                 4        R10001   885737.0  O2378625  2018-12-29 20:19:17
# 4                 5        R10001  1505751.0  O2211385  2018-12-05 19:48:52
# ...             ...           ...        ...       ...                  ...
# 2392361     2392362        R10008   725063.0   O143458  2018-01-23 16:03:35
# 2392362     2392363        R10008   776825.0   O353677  2018-02-22 19:50:28
# 2392363     2392364        R10008  1591109.0  O1842682  2018-10-14 21:06:12
# 2392364     2392365        R10008  1015196.0  O1017090  2018-05-31 16:22:11
# 2392365     2392366        R10008   808526.0  O2212656  2018-12-05 22:41:10
#
# ...

# %%
df_orders
# Out:
#          Unnamed: 0 RESTAURANT_ID       ...1  ORDER_ID             DATETIME  \
# 0                 1        R10001        0.0  O2226026  2018-12-07 19:17:45
# 1                 2        R10001   797162.0  O1734393  2018-09-28 14:41:22
# 2                 3        R10001   797163.0  O1638120  2018-09-13 18:43:51
# 3                 4        R10001   885737.0  O2378625  2018-12-29 20:19:17
# 4                 5        R10001  1505751.0  O2211385  2018-12-05 19:48:52
# ...             ...           ...        ...       ...                  ...
# 2392361     2392362        R10008   725063.0   O143458  2018-01-23 16:03:35
# 2392362     2392363        R10008   776825.0   O353677  2018-02-22 19:50:28
# 2392363     2392364        R10008  1591109.0  O1842682  2018-10-14 21:06:12
# 2392364     2392365        R10008  1015196.0  O1017090  2018-05-31 16:22:11
# 2392365     2392366        R10008   808526.0  O2212656  2018-12-05 22:41:10
#
# ...

# %%
df_orders[["DATE","TIME"]] = df_orders["DATETIME"].str.split(expand=True)

# %%
df_orders
# Out:
#          Unnamed: 0 RESTAURANT_ID       ...1  ORDER_ID             DATETIME  \
# 0                 1        R10001        0.0  O2226026  2018-12-07 19:17:45
# 1                 2        R10001   797162.0  O1734393  2018-09-28 14:41:22
# 2                 3        R10001   797163.0  O1638120  2018-09-13 18:43:51
# 3                 4        R10001   885737.0  O2378625  2018-12-29 20:19:17
# 4                 5        R10001  1505751.0  O2211385  2018-12-05 19:48:52
# ...             ...           ...        ...       ...                  ...
# 2392361     2392362        R10008   725063.0   O143458  2018-01-23 16:03:35
# 2392362     2392363        R10008   776825.0   O353677  2018-02-22 19:50:28
# 2392363     2392364        R10008  1591109.0  O1842682  2018-10-14 21:06:12
# 2392364     2392365        R10008  1015196.0  O1017090  2018-05-31 16:22:11
# 2392365     2392366        R10008   808526.0  O2212656  2018-12-05 22:41:10
#
# ...

# %%
df_ord_1 = df_orders[["RESTAURANT_ID", "DATE","TIME", "NAME", "TYPE", "DRINKS", "COOKIES", "MAIN_NAME", "BASE_NAME", "SIDE_1_NAME", "SIDE_2_NAME"]]

# %%
df_ord_1
# Out:
#         RESTAURANT_ID        DATE      TIME          NAME      TYPE  DRINKS  \
# 0              R10001  2018-12-07  19:17:45      Columbia    PICKUP       2
# 1              R10001  2018-09-28  14:41:22      Columbia    PICKUP       0
# 2              R10001  2018-09-13  18:43:51      Columbia    PICKUP       0
# 3              R10001  2018-12-29  20:19:17      Columbia  IN_STORE       0
# 4              R10001  2018-12-05  19:48:52      Columbia  IN_STORE       0
# ...               ...         ...       ...           ...       ...     ...
# 2392361        R10008  2018-01-23  16:03:35  Williamsburg  IN_STORE       0
# 2392362        R10008  2018-02-22  19:50:28  Williamsburg  IN_STORE       0
# 2392363        R10008  2018-10-14  21:06:12  Williamsburg  IN_STORE       0
# 2392364        R10008  2018-05-31  16:22:11  Williamsburg  IN_STORE       0
# 2392365        R10008  2018-12-05  22:41:10  Williamsburg  IN_STORE       0
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df_ord_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392366 entries, 0 to 2392365
# Data columns (total 11 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   RESTAURANT_ID  object
#  1   DATE           object
#  2   TIME           object
#  3   NAME           object
#  4   TYPE           object
#  5   DRINKS         int64
#  6   COOKIES        int64
#  7   MAIN_NAME      object
#  8   BASE_NAME      object
#  9   SIDE_1_NAME    object
#  10  SIDE_2_NAME    object
# dtypes: int64(2), object(9)
# memory usage: 200.8+ MB

# %%
df_orders.describe()
# Out:
#          Unnamed: 0          ...1        DRINKS       COOKIES
# count  2.392366e+06  2.392366e+06  2.392366e+06  2.392366e+06
# mean   1.196184e+06  1.196182e+06  2.456296e-01  2.602909e-01
# std    6.906167e+05  6.906167e+05  6.641652e-01  5.589882e-01
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.980922e+05  5.980912e+05  0.000000e+00  0.000000e+00
# 50%    1.196184e+06  1.196182e+06  0.000000e+00  0.000000e+00
# 75%    1.794275e+06  1.794274e+06  0.000000e+00  0.000000e+00
# max    2.392366e+06  2.392365e+06  3.000000e+00  2.000000e+00

# %%
df_ord_1.TYPE.value_counts(normalize = True)
# Out:
# IN_STORE    0.718399
# PICKUP      0.167476
# DELIVERY    0.114126
# Name: TYPE, dtype: float64

# %%
df_ord_1.TYPE.value_counts(normalize = True).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_ord_1.RESTAURANT_ID.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_ord_1.NAME.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_ord_1.SIDE_1_NAME.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_ord_1.SIDE_2_NAME.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_ord_1.head()
# Out:
#   RESTAURANT_ID        DATE      TIME      NAME      TYPE  DRINKS  COOKIES  \
# 0        R10001  2018-12-07  19:17:45  Columbia    PICKUP       2        2
# 1        R10001  2018-09-28  14:41:22  Columbia    PICKUP       0        0
# 2        R10001  2018-09-13  18:43:51  Columbia    PICKUP       0        0
# 3        R10001  2018-12-29  20:19:17  Columbia  IN_STORE       0        0
# 4        R10001  2018-12-05  19:48:52  Columbia  IN_STORE       0        2
#
#                          MAIN_NAME              BASE_NAME         SIDE_1_NAME  \
# 0                              NaN                    NaN                 NaN
# 1  Herb Roasted Chicken Marketbowl  Farm Greens with Mint           Snap Peas
# 2  Herb Roasted Chicken Marketbowl  Farm Greens with Mint  Cashew Kale Caesar
# 3                              NaN                    NaN                 NaN
# 4                              NaN                    NaN                 NaN
#
#                        SIDE_2_NAME
# ...

# %%
df_sord = pd.DataFrame(pd.read_csv("C:\\Users\\JSILL\\Downloads\\simplified_orders.csv"))
print(df_sord)
# Out:
#          ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026  2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827  2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957  2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863  2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303  2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                  ...           ...       ...     ...
# 2392361  O1954914  2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052  2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030  2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869  2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630  2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2
# 0            2.0  NaN  NaN    NaN    NaN
# ...

# %%
df_sord.head()
# Out:
#    ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES  \
# 0  O2226026  2018-12-07 19:17:45        R10001    PICKUP     2.0      2.0
# 1  O1279827  2018-07-14 21:23:43        R10006  IN_STORE     0.0      0.0
# 2   O689957  2018-04-12 13:14:42        R10002    PICKUP     0.0      2.0
# 3  O1497863  2018-08-21 18:14:23        R10007  IN_STORE     1.0      0.0
# 4  O1443303  2018-08-12 18:04:44        R10006  DELIVERY     0.0      0.0
#
#   MAIN BASE SIDE_1 SIDE_2
# 0  NaN  NaN    NaN    NaN
# 1  NaN  NaN    NaN    NaN
# 2   I1   I7    I11     I8
# 3   I1   I5    I10     I9
# 4   I1   I6    I10    I11

# %%
df_ordloc = pd.DataFrame(pd.read_csv("C:\\Users\\JSILL\\Downloads\\rest_location.csv"))
print(df_ordloc)
# Out:
#           location         day  number of orders  percentage of deliveries
# 0      Bryant Park  2018-01-01               394                  0.000000
# 1      Bryant Park  2018-01-02               807                  0.000000
# 2      Bryant Park  2018-01-03               744                  0.000000
# 3      Bryant Park  2018-01-04               791                  0.000000
# 4      Bryant Park  2018-01-05               677                  0.000000
# ...            ...         ...               ...                       ...
# 2801  Williamsburg  2018-12-27               928                  0.095905
# 2802  Williamsburg  2018-12-28               948                  0.113924
# 2803  Williamsburg  2018-12-29               993                  0.094663
# 2804  Williamsburg  2018-12-30               949                  0.112750
# 2805  Williamsburg  2018-12-31               931                  0.110634
#
# [2806 rows x 4 columns]

# %%
    df_ordloc.rename(columns = {'location':'LOC','day':'DAY','number of orders':'ORDERS','percentage of deliveries':'DELPER'}, inplace = True)

# %%
df_ordloc.head()
# Out:
#            LOC         DAY  ORDERS  DELPER
# 0  Bryant Park  2018-01-01     394     0.0
# 1  Bryant Park  2018-01-02     807     0.0
# 2  Bryant Park  2018-01-03     744     0.0
# 3  Bryant Park  2018-01-04     791     0.0
# 4  Bryant Park  2018-01-05     677     0.0

# %%
df_ordloc.plot(kind='scatter',x='LOC',y='ORDERS',color='red')
plt.show()

# %%
df_ordloc.groupby(['LOC']).plot(kind='scatter', x='DAY', y='ORDERS',color='red')
plt.xticks(rotation = 90)
plt.figure(figsize=self.figsize)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2cb830afcfa2> in <module>
#       1 df_ordloc.groupby(['LOC']).plot(kind='scatter', x='DAY', y='ORDERS',color='red')
#       2 plt.xticks(rotation = 90)
# ----> 3 plt.figure(figsize=self.figsize)
#       4 plt.show()
#
# NameError: name 'self' is not defined

# %%
df_ordlocx = df_ordloc.drop('DELPER',axis=1)

# %%
df_williamsburg = df_ordlocx.loc[df_ordlocx['LOC'] == 'Williamsburg']

# %%
df_williamsburg
# Out:
#                LOC         DAY  ORDERS
# 2441  Williamsburg  2018-01-01     821
# 2442  Williamsburg  2018-01-02     840
# 2443  Williamsburg  2018-01-03     915
# 2444  Williamsburg  2018-01-04     875
# 2445  Williamsburg  2018-01-05     801
# ...            ...         ...     ...
# 2801  Williamsburg  2018-12-27     928
# 2802  Williamsburg  2018-12-28     948
# 2803  Williamsburg  2018-12-29     993
# 2804  Williamsburg  2018-12-30     949
# 2805  Williamsburg  2018-12-31     931
#
# [365 rows x 3 columns]

# %%
df_bryant = df_ordlocx.loc[df_ordlocx['LOC'] == 'Bryant Park']
df_bryantx =  pd.to_datetime(df_bryant['DAY']).dt.strftime('%m')
df_bryant.insert(2,'MON',df_bryantx,True)
df_bryant = df_bryant.drop('DAY',axis=1)
df_bryant
# Out:
#              LOC MON  ORDERS
# 0    Bryant Park  01     394
# 1    Bryant Park  01     807
# 2    Bryant Park  01     744
# 3    Bryant Park  01     791
# 4    Bryant Park  01     677
# ..           ...  ..     ...
# 256  Bryant Park  12     521
# 257  Bryant Park  12    1019
# 258  Bryant Park  12    1034
# 259  Bryant Park  12    1016
# 260  Bryant Park  12    1001
#
# [261 rows x 3 columns]

# %%
df_bryant.plot(kind='scatter',x='MON',y='ORDERS',color='red')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10,10)
plt.scatter(x='MON', y='ORDERS', data=df_bryant)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.show()

# %%
df_x =  pd.to_datetime(df_ordloc['DAY']).dt.strftime('%m')
df_ordloc.insert(3,'MON',df_x,True)
df_ordloc
# Out:
#                LOC         DAY  ORDERS MON    DELPER
# 0      Bryant Park  2018-01-01     394  01  0.000000
# 1      Bryant Park  2018-01-02     807  01  0.000000
# 2      Bryant Park  2018-01-03     744  01  0.000000
# 3      Bryant Park  2018-01-04     791  01  0.000000
# 4      Bryant Park  2018-01-05     677  01  0.000000
# ...            ...         ...     ...  ..       ...
# 2801  Williamsburg  2018-12-27     928  12  0.095905
# 2802  Williamsburg  2018-12-28     948  12  0.113924
# 2803  Williamsburg  2018-12-29     993  12  0.094663
# 2804  Williamsburg  2018-12-30     949  12  0.112750
# 2805  Williamsburg  2018-12-31     931  12  0.110634
#
# [2806 rows x 5 columns]

# %%
plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='LOC', y='ORDERS', data=df_ordloc, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Location (LOC)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_br = df_ordloc.loc[df_ordloc['LOC'] == 'Bryant Park']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_br, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_co = df_ordloc.loc[df_ordloc['LOC'] == 'Columbia']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_co, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_mi = df_ordloc.loc[df_ordloc['LOC'] == 'Midtown']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_mi, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_fl = df_ordloc.loc[df_ordloc['LOC'] == 'Flatiron']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_fl, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_nyu = df_ordloc.loc[df_ordloc['LOC'] == 'NYU']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_nyu, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_ws = df_ordloc.loc[df_ordloc['LOC'] == 'Upper West Side']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_ws, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_es = df_ordloc.loc[df_ordloc['LOC'] == 'Upper East Side']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_es, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()

# %%
df_wi = df_ordloc.loc[df_ordloc['LOC'] == 'Williamsburg']

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('bmh')
plt.scatter(x='MON', y='ORDERS', data=df_wi, s='ORDERS', c='DELPER', vmin=0, vmax=100, cmap='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Month (MON)', fontsize=14) 
plt.ylabel('Sales (ORDERS)', fontsize=14)
plt.colorbar(label='Delivery %')
plt.show()
